# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
# Your Code Here
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv ("../data/Fitbit2.csv")

# %%
fitbit.sample(5)
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary
# 154  2015-10-09            2549   8718      6.48      10            976.000  \
# 117  2015-09-02            3009   1033      7.68      16            770.000
# 29   2015-06-06            3436   1548     11.50      11            520.000
# 115  2015-08-31            3136  10757      7.99      15              1.187
# 315  2016-03-17             315  14577     11.46      17            823.000
#
#      Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active
# 154                      65                      0                    0  \
# 117                     248                     16                   15
# 29                      246                     78                   42
# 115                     145                     43                   65
# 315                     162                     10                   81
#
#      Activity Calories  ...  Distance_miles       Days  Days_encoded
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here

fitbit.groupby("Months_encoded")[["Steps"]].agg("count")
# Out:
#                 Steps
# Months_encoded
# 1                  31
# 2                  30
# 3                  31
# 4                  30
# 5                  31
# 6                  30
# 7                  31
# 8                  31
# 9                  30
# 10                 31
# 11                 30
# 12                 31

# %%
fitbit_barplot_steps = sns.barplot(x=fitbit["Months_encoded"], y=fitbit["Steps"], palette="magma", errorbar=None);

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
sns.scatterplot(x="Minutes Lightly Active", y="Steps", data =fitbit);

# %%
sns.scatterplot(x="Minutes Very Active", y="Steps", data =fitbit);

# %%
sns.scatterplot(x="Minutes Sedentary", y="Steps", data =fitbit);

# %%
pairs = [("Minutes Lightly Active", "Steps"), ("Minutes Very Active", "Steps"), ("Minutes Sedentary", "Steps")]

# %%
#DRAFT
for x, y in pairs:
    sns.scatterplot(x=x, y=y, data=fitbit).get_figure()
    filename = ("plot" + x +."jpg")
    plt.savefig("path")
    plt.clf() # Clear the plot to avoid overplotting
    
plt.show()

# %%
cols = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

for col in cols:
    plt.figure()
    plt.xlabel('Steps')
    plt.ylabel(col)
    plt.scatter(fitbit['Steps'], fitbit[col], color= np.random.rand(3,))
    plt.savefig(col + '.png', dpi=600)

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv ("../data/titanic.csv")

# %%
titanic.sample()
# Out:
#       PassengerId  Survived  Pclass                          Name  Gender
# 1060         1061       NaN       3  Hellstrom, Miss. Hilda Maria  female  \
#
#        Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 1060  22.0      0      0   7548  8.9625    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include=['object']).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
titanic.plot(figsize=(12,6));

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age, bins = 20); 
# histograms: work with numerical data stored by bins (ranges)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# SKIP

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
by setting a value to bins = x changes the appearance of the graph.
     < size: too many bars, so you may have a graph difficult to interpret
     > size: too few bars, so you can lose details
"""
# Out:
# '\nby setting a value to bins = x changes the appearance of the graph.\n     < size: too many bars, so you may have a graph difficult to interpret\n     > size: too few bars, so you can lose details\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age, kde=True, color = "green");

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic['Gender'].value_counts().plot(kind='bar', color=['purple', 'salmon'])
plt.xticks(rotation=0.5);

# %%
# Method 2 - seaborn
sns.countplot(x=titanic.Gender, palette="magma");

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x=titanic.Pclass, palette="mako");

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x="Age", data=titanic, palette="viridis");

# %%
"""
Box plot: plot that is used to show the distribution of a numeric variable

"""
# Out:
# '\nBox plot: plot that is used to show the distribution of a numeric variable\n\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
- BLUE BOX: interquartile range (IQR)
    Represents the centile 50 (that is the same as the median)
        the median spits the data in two
            50 % is below
            50 % is above
- OUTLIERS(valores atípicos): 
- WHISKERS:(lines extending from the box) 
    Represent the range of the data outside of the IQR. 
    Common method: extend the whiskers 1.5 times the IQR from the box. 
    as individual points.
"""
# Out:
# '\n- BLUE BOX: interquartile range (IQR)\n    Represents the centile 50 (that is the same as the median)\n        the median spits the data in two\n            50 % is below\n            50 % is above\n- OUTLIERS(valores atípicos): \n- WHISKERS:(lines extending from the box) \n    Represent the range of the data outside of the IQR. \n    Common method: extend the whiskers 1.5 times the IQR from the box. \n    as individual points.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# STOP
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
